# %%
import os
import pandas as pd

os.chdir('c:/Users/cunn2/OneDrive/DSML/Project/thesis-repo/')

from plagdet.src.defaults import *

# %%
import pickle

with open('custom_vectors.pkl', 'rb') as f:
    custom_vectors = pickle.load(f)

metadata = pd.read_pickle(SYNTHETIC_PAIR_METADATA_PATH)
tracker = pd.read_csv(SYNTHETIC_PAIR_TRACKER_PATH, index_col='pair_id')

pair_id = 10

original_path = tracker.loc[pair_id, 'original_midi_path']
plagiarised_path = tracker.loc[pair_id, 'plagiarised_midi_path']

metadata_row = metadata.loc[pair_id]

for key, value in metadata_row.items():
    print(f'{key}: {value}')
# Out:
# pair_id: 10
# midi_modifier_config: MidiModifierConfig(use_shift_entire_midi_pitch=True, entire_shift_semitone=12, use_shift_selected_notes_pitch=True, selected_notes_pitch_shifts=[((17, 19), -2), ((9, 10), 0)], use_change_note_durations=True, note_scale_factors=[((4, 7), 2.5623164478556983)], use_delete_notes=True, notes_to_delete=[(2, 5)])
# segment_starting_bar: 79
# segment_starting_time_secs: 158.0
# segment_insertion_starting_bar: 10
# segment_insertion_starting_time_secs: 20.0

# %%
from typing import Dict, Any

def metadata_row_to_dict(metadata_row) -> Dict[str, Any]:
    return {
        "pair_id": int(metadata_row['pair_id']),
        "segment_starting_bar": int(metadata_row['segment_starting_bar']),
        "segment_starting_time_secs": float(metadata_row['segment_starting_time_secs']),
        "segment_insertion_starting_bar": int(metadata_row['segment_insertion_starting_bar']),
        "segment_insertion_starting_time_secs": float(metadata_row['segment_insertion_starting_time_secs'])
    }


def midi_modifier_config_to_dict(midi_modifier_config):
    return {
        "use_shift_entire_midi_pitch": midi_modifier_config.use_shift_entire_midi_pitch,
        "entire_shift_semitone": midi_modifier_config.entire_shift_semitone,
        "use_shift_selected_notes_pitch": midi_modifier_config.use_shift_selected_notes_pitch,
        "selected_notes_pitch_shifts": midi_modifier_config.selected_notes_pitch_shifts,
        "use_change_note_durations": midi_modifier_config.use_change_note_durations,
        "note_scale_factors": midi_modifier_config.note_scale_factors,
        "use_delete_notes": midi_modifier_config.use_delete_notes,
    }

# %%
midi_modifier_config_to_dict(metadata_row['midi_modifier_config'])
# Out:
# {'use_shift_entire_midi_pitch': True,
#  'entire_shift_semitone': 12,
#  'use_shift_selected_notes_pitch': True,
#  'selected_notes_pitch_shifts': [((17, 19), -2), ((9, 10), 0)],
#  'use_change_note_durations': True,
#  'note_scale_factors': [((4, 7), 2.5623164478556983)],
#  'use_delete_notes': True}

# %%
import chromadb
from chromadb.utils import embedding_functions
import numpy as np

# Initialize Chroma client
client = chromadb.Client()

# Create a collection
collection = client.create_collection("midi_embeddings_cleared")
# Out:
# [2024-09-09 14:53:32] [DEBUG] Resetting dropped connection: us.i.posthog.com
# [2024-09-09 14:53:33] [DEBUG] https://us.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15

# %%
def filter_empty_embeddings(embeddings_dict):
    return {start_bar: embedding for start_bar, embedding in embeddings_dict.items() if len(embedding) > 0}

# %%
# Get the original file embeddings
original_embeddings = custom_vectors[original_path]
filtered_original_embeddings = filter_empty_embeddings(original_embeddings)

# Prepare the documents, metadatas, and ids
documents = []
metadatas = []
ids = []

embeddings_list = []

for start_bar, embedding in filtered_original_embeddings.items():
    native_embedding = [float(val) for val in embedding]
    # if len(native_embedding) > 0:
    embeddings_list.append(native_embedding)
    doc_id = f"{pair_id}_original_{start_bar}"
    ids.append(doc_id)
    documents.append(f"Original MIDI segment starting at bar {start_bar}")
    metadatas.append({
        "file_type": "original",
        "processed_directory": "maestro",
        "original_path": original_path,
        "plagiarised_path": plagiarised_path,
        **metadata_row_to_dict(metadata_row)
    })

# Add the original embeddings to the collection
collection.add(
    embeddings=embeddings_list,
    documents=documents,
    metadatas=metadatas,
    ids=ids
)
# Out:
# [2024-09-09 15:03:33] [DEBUG] Starting component LocalHnswSegment
# [2024-09-09 15:03:33] [DEBUG] https://us.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15

# %%
collection = client.create_collection(
    name="midi_embeddings_cosine",
    metadata={"hnsw:space": "cosine"}  # This sets the metric to cosine similarity
)
# Out:
# [2024-09-09 15:03:23] [DEBUG] Resetting dropped connection: us.i.posthog.com
# [2024-09-09 15:03:23] [DEBUG] https://us.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15

# %%
# Get the plagiarised file embeddings
plagiarised_embeddings = custom_vectors[plagiarised_path]
filtered_plagiarised_embeddings = filter_empty_embeddings(plagiarised_embeddings)

# Query the collection for each plagiarised embedding
for start_bar, embedding in filtered_plagiarised_embeddings.items():
    native_embedding = [float(val) for val in embedding]
    results = collection.query(
        query_embeddings=[native_embedding],
        n_results=1
    )
    
    print(f"Plagiarised segment starting at bar {start_bar}:")
    print(f"Closest match: {results['documents'][0][0]}")
    print(f"Metadata: {results['metadatas'][0][0]}")
    print(f"Distance: {results['distances'][0][0]}")
    print()
# Out:
# Plagiarised segment starting at bar 3:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 858.943115234375
#
# Plagiarised segment starting at bar 4:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 904.569580078125
#
# Plagiarised segment starting at bar 5:
# Closest match: Original MIDI segment starting at bar 9
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 877.7001953125
#
# Plagiarised segment starting at bar 6:
# Closest match: Original MIDI segment starting at bar 79
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 954.6156616210938
#
# Plagiarised segment starting at bar 7:
# Closest match: Original MIDI segment starting at bar 49
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 852.7322998046875
#
# Plagiarised segment starting at bar 8:
# Closest match: Original MIDI segment starting at bar 86
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 887.3720092773438
#
# Plagiarised segment starting at bar 9:
# Closest match: Original MIDI segment starting at bar 38
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 871.4720458984375
#
# Plagiarised segment starting at bar 10:
# Closest match: Original MIDI segment starting at bar 28
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 868.5232543945312
#
# Plagiarised segment starting at bar 11:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 887.29150390625
#
# Plagiarised segment starting at bar 12:
# Closest match: Original MIDI segment starting at bar 28
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 914.792236328125
#
# Plagiarised segment starting at bar 13:
# Closest match: Original MIDI segment starting at bar 30
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 835.0166015625
#
# Plagiarised segment starting at bar 14:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 882.4290771484375
#
# Plagiarised segment starting at bar 15:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 858.2057495117188
#
# Plagiarised segment starting at bar 16:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 902.0448608398438
#
# Plagiarised segment starting at bar 17:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 886.673095703125
#
# Plagiarised segment starting at bar 18:
# Closest match: Original MIDI segment starting at bar 68
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 914.3818359375
#
# Plagiarised segment starting at bar 19:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 917.75048828125
#
# Plagiarised segment starting at bar 20:
# Closest match: Original MIDI segment starting at bar 8
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 908.8623046875
#
# Plagiarised segment starting at bar 21:
# Closest match: Original MIDI segment starting at bar 8
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 934.4754638671875
#
# Plagiarised segment starting at bar 22:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 941.56591796875
#
# Plagiarised segment starting at bar 23:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 892.8184204101562
#
# Plagiarised segment starting at bar 24:
# Closest match: Original MIDI segment starting at bar 12
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 919.3462524414062
#
# Plagiarised segment starting at bar 25:
# Closest match: Original MIDI segment starting at bar 79
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 935.687744140625
#
# Plagiarised segment starting at bar 26:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 909.542236328125
#
# Plagiarised segment starting at bar 27:
# Closest match: Original MIDI segment starting at bar 5
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 894.1337280273438
#
# Plagiarised segment starting at bar 28:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 868.344482421875
#
# Plagiarised segment starting at bar 29:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 879.2544555664062
#
# Plagiarised segment starting at bar 30:
# Closest match: Original MIDI segment starting at bar 49
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 867.9287109375
#
# Plagiarised segment starting at bar 31:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 859.3139038085938
#
# Plagiarised segment starting at bar 32:
# Closest match: Original MIDI segment starting at bar 49
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 899.1287841796875
#
# Plagiarised segment starting at bar 33:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 924.201416015625
#
# Plagiarised segment starting at bar 34:
# Closest match: Original MIDI segment starting at bar 55
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 893.30859375
#
# Plagiarised segment starting at bar 35:
# Closest match: Original MIDI segment starting at bar 86
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 871.80712890625
#
# Plagiarised segment starting at bar 36:
# Closest match: Original MIDI segment starting at bar 8
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 947.6425170898438
#
# Plagiarised segment starting at bar 37:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 891.6104736328125
#
# Plagiarised segment starting at bar 38:
# Closest match: Original MIDI segment starting at bar 9
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 910.6380615234375
#
# Plagiarised segment starting at bar 39:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 848.56640625
#
# Plagiarised segment starting at bar 40:
# Closest match: Original MIDI segment starting at bar 56
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 904.9049072265625
#
# Plagiarised segment starting at bar 41:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 907.480712890625
#
# Plagiarised segment starting at bar 42:
# Closest match: Original MIDI segment starting at bar 39
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 832.889892578125
#
# Plagiarised segment starting at bar 43:
# Closest match: Original MIDI segment starting at bar 83
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 870.1461791992188
#
# Plagiarised segment starting at bar 44:
# Closest match: Original MIDI segment starting at bar 30
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 874.0322265625
#
# Plagiarised segment starting at bar 45:
# Closest match: Original MIDI segment starting at bar 12
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 830.2119140625
#
# Plagiarised segment starting at bar 46:
# Closest match: Original MIDI segment starting at bar 76
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 885.4609985351562
#
# Plagiarised segment starting at bar 47:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 925.1192626953125
#
# Plagiarised segment starting at bar 48:
# Closest match: Original MIDI segment starting at bar 79
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 937.9664306640625
#
# Plagiarised segment starting at bar 49:
# Closest match: Original MIDI segment starting at bar 49
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 890.771728515625
#
# Plagiarised segment starting at bar 50:
# Closest match: Original MIDI segment starting at bar 28
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 862.5811767578125
#
# Plagiarised segment starting at bar 51:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 851.3431396484375
#
# Plagiarised segment starting at bar 52:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 950.1748046875
#
# Plagiarised segment starting at bar 53:
# Closest match: Original MIDI segment starting at bar 12
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 908.5107421875
#
# Plagiarised segment starting at bar 54:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 907.739501953125
#
# Plagiarised segment starting at bar 55:
# Closest match: Original MIDI segment starting at bar 30
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 856.308349609375
#
# Plagiarised segment starting at bar 56:
# Closest match: Original MIDI segment starting at bar 85
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 899.9615478515625
#
# Plagiarised segment starting at bar 57:
# Closest match: Original MIDI segment starting at bar 72
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 833.99365234375
#
# Plagiarised segment starting at bar 58:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 745.2210693359375
#
# Plagiarised segment starting at bar 59:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 840.6434326171875
#
# Plagiarised segment starting at bar 60:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 865.5950927734375
#
# Plagiarised segment starting at bar 61:
# Closest match: Original MIDI segment starting at bar 8
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 920.0743408203125
#
# Plagiarised segment starting at bar 62:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 891.9295043945312
#
# Plagiarised segment starting at bar 63:
# Closest match: Original MIDI segment starting at bar 39
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 886.42822265625
#
# Plagiarised segment starting at bar 64:
# Closest match: Original MIDI segment starting at bar 68
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 895.6944580078125
#
# Plagiarised segment starting at bar 65:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 862.97021484375
#
# Plagiarised segment starting at bar 66:
# Closest match: Original MIDI segment starting at bar 22
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 872.0661010742188
#
# Plagiarised segment starting at bar 67:
# Closest match: Original MIDI segment starting at bar 85
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 932.8883056640625
#
# Plagiarised segment starting at bar 68:
# Closest match: Original MIDI segment starting at bar 9
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 958.5883178710938
#
# Plagiarised segment starting at bar 69:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 906.0330200195312
#
# Plagiarised segment starting at bar 70:
# Closest match: Original MIDI segment starting at bar 85
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 954.9461059570312
#
# Plagiarised segment starting at bar 71:
# Closest match: Original MIDI segment starting at bar 37
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 819.69580078125
#
# Plagiarised segment starting at bar 72:
# Closest match: Original MIDI segment starting at bar 53
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 848.5452880859375
#
# Plagiarised segment starting at bar 73:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 898.1083984375
#
# Plagiarised segment starting at bar 74:
# Closest match: Original MIDI segment starting at bar 51
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 921.317626953125
#
# Plagiarised segment starting at bar 75:
# Closest match: Original MIDI segment starting at bar 17
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 907.4510498046875
#
# Plagiarised segment starting at bar 76:
# Closest match: Original MIDI segment starting at bar 31
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 897.669921875
#
# Plagiarised segment starting at bar 77:
# Closest match: Original MIDI segment starting at bar 9
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 879.5963134765625
#
# Plagiarised segment starting at bar 78:
# Closest match: Original MIDI segment starting at bar 1
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 861.212158203125
#
# Plagiarised segment starting at bar 79:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 878.0473022460938
#
# Plagiarised segment starting at bar 80:
# Closest match: Original MIDI segment starting at bar 22
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 893.0953369140625
#
# Plagiarised segment starting at bar 81:
# Closest match: Original MIDI segment starting at bar 80
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 924.4660034179688
#
# Plagiarised segment starting at bar 82:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 874.0010986328125
#
# Plagiarised segment starting at bar 83:
# Closest match: Original MIDI segment starting at bar 85
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 877.0451049804688
#
# Plagiarised segment starting at bar 84:
# Closest match: Original MIDI segment starting at bar 16
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 845.361572265625
#
# Plagiarised segment starting at bar 85:
# Closest match: Original MIDI segment starting at bar 78
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 867.4647216796875
#
# Plagiarised segment starting at bar 86:
# Closest match: Original MIDI segment starting at bar 36
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 902.9930419921875
#
# Plagiarised segment starting at bar 87:
# Closest match: Original MIDI segment starting at bar 3
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 826.825927734375
#
# Plagiarised segment starting at bar 88:
# Closest match: Original MIDI segment starting at bar 21
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 926.2990112304688
# [2024-09-09 14:57:43] [DEBUG] Resetting dropped connection: us.i.posthog.com
# [2024-09-09 14:57:43] [DEBUG] https://us.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15

# %%
# Get the plagiarised file embeddings
plagiarised_embeddings = custom_vectors[plagiarised_path]
filtered_plagiarised_embeddings = filter_empty_embeddings(plagiarised_embeddings)

# List to store all results
all_results = []

# Query the collection for each plagiarised embedding
for start_bar, embedding in filtered_plagiarised_embeddings.items():
    native_embedding = [float(val) for val in embedding]
    results = collection.query(
        query_embeddings=[native_embedding],
        n_results=1
    )
    
    all_results.append({
        "plagiarised_start_bar": start_bar,
        "closest_match": results['documents'][0][0],
        "metadata": results['metadatas'][0][0],
        "distance": results['distances'][0][0]
    })

# Sort all results by distance (ascending order)
sorted_results = sorted(all_results, key=lambda x: x['distance'])

# Print the top 5 closest matches
print("Top 5 closest matches:")
for i, result in enumerate(sorted_results[:5], 1):
    print(f"\nMatch {i}:")
    print(f"Plagiarised segment starting at bar {result['plagiarised_start_bar']}:")
    print(f"Closest match: {result['closest_match']}")
    print(f"Metadata: {result['metadata']}")
    print(f"Distance: {result['distance']}")
# Out:
# Top 5 closest matches:
#
# Match 1:
# Plagiarised segment starting at bar 71:
# Closest match: Original MIDI segment starting at bar 37
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 0.821150541305542
#
# Match 2:
# Plagiarised segment starting at bar 39:
# Closest match: Original MIDI segment starting at bar 40
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 0.8461796641349792
#
# Match 3:
# Plagiarised segment starting at bar 34:
# Closest match: Original MIDI segment starting at bar 55
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 0.849489688873291
#
# Match 4:
# Plagiarised segment starting at bar 43:
# Closest match: Original MIDI segment starting at bar 83
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 0.8499898910522461
#
# Match 5:
# Plagiarised segment starting at bar 20:
# Closest match: Original MIDI segment starting at bar 13
# Metadata: {'file_type': 'original', 'original_path': 'plagdet/data/synthetic_dataset/pairs/original\\original_10.mid', 'pair_id': 10, 'plagiarised_path': 'plagdet/data/synthetic_dataset/pairs/plagiarised\\plagiarised_10.mid', 'processed_directory': 'maestro', 'segment_insertion_starting_bar': 10, 'segment_insertion_starting_time_secs': 20.0, 'segment_starting_bar': 79, 'segment_starting_time_secs': 158.0}
# Distance: 0.8523238897323608
# [2024-09-09 15:03:50] [DEBUG] https://us.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15
